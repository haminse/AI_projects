# %% [markdown]
# # 뉴스 요약본 만들기
# seq2seq 모델을 통해서 Abstractive summarization 방식의 텍스트 요약기 만들기

# %% [markdown]
# ## seq2seq 개요
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# seq2seq은 두 개의 RNN 아키텍처를 사용하여 입력 시퀀스로부터 출력 시퀀스를 생성해 내는 자연어 생성 모델, 기계번역에 주로 사용
#
#
# #### Process
#
# - 원문을 첫 번째 RNN인 인코더로 입력하면, 인코더는 이를 하나의 고정된 벡터로 변환. 이 벡터를 문맥 정보를 가지고 있는 벡터라고 하여 컨텍스트 벡터(context vector)라고 함
#
#
# - 두 번째 RNN인 디코더는 이 컨텍스트 벡터를 전달받아 한 단어씩 생성해내서 요약 문장을 완성

# %% [markdown]
# ### LSTM과 컨텍스트 벡터
#
# time step의 셀에 hidden state뿐만 아니라, cell state도 함께 전달한다는 점에서 위의 바닐라 RNN과 다름.
#
#
# 다시 말해, 인코더가 디코더에 전달하는 컨텍스트 벡터 또한 hidden state h와 cell state c 두 개의 값 모두 존재해야 함.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 어텐션 메커니즘을 통한 새로운 컨텍스트 벡터 사용하기

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 우리는 기존에 배운 seq2seq를 수정하고, 새로운 모듈을 붙여 모델의 성능을 높여볼 거예요. 기존의 seq2seq는 인코더의 마지막 time step의 hidden state를 컨텍스트 벡터로 사용했어요. 하지만 RNN 계열의 인공 신경망(바닐라 RNN, LSTM, GRU)의 한계로 인해 이 컨텍스트 정보에는 이미 입력 시퀀스의 많은 정보가 손실이 된 상태가 됩니다.
#
# 어텐션 메커니즘(Attention Mechanism) 은 이와 달리, 인코더의 모든 step의 hidden state의 정보가 컨텍스트 벡터에 전부 반영되도록 하는 것입니다. 하지만 인코더의 모든 hidden state가 동일한 비중으로 반영되는 것이 아니라, 디코더의 현재 time step의 예측에 인코더의 각 step이 얼마나 영향을 미치는지에 따른 가중합으로 계산되는 방식입니다.
#
# ![image-3.png](attachment:image-3.png)
#
# 여기서 주의해야 할 것은, 컨텍스트 벡터를 구성하기 위한 인코더 hidden state의 가중치 값은 디코더의 현재 스텝이 어디냐에 따라 계속 달라진다는 점입니다. 즉, 디코더의 현재 문장 생성 부위가 주어부인지 술어부인지 목적어인지 등에 따라 인코더가 입력 데이터를 해석한 컨텍스트 벡터가 다른 값이 된다는 것입니다. 이와 달리, 기본적인 seq2seq 모델에서 컨텍스트 벡터는 디코더의 현재 스텝 위치에 무관하게 한번 계산되면 고정값을 가집니다.

# %% [markdown]
# #### 요약
#
# - seq2seq를 사용합니다.
# - RNN 계열 중 LSTM을 사용하므로 hidden state뿐만 아니라 cell state도 사용해야 합니다.
# - 디코더의 예측 시퀀스에는 시작 토큰 SOS와 예측 토큰 EOS를 시퀀스의 앞, 뒤로 붙입니다.
# - seq2seq를 구동시키면 디코더는 시작 토큰을 입력받아 예측을 시작합니다.
# - seq2seq 기본 모델과 달리, 어텐션 메커니즘을 이용해 인코더의 hidden state의 중요도를 - 취합한 컨텍스트 벡터를 디코더 스텝별로 계산합니다.
# - 계산된 컨텍스트 벡터를 이용해서 디코더는 다음 등장할 단어를 예측합니다.

# %% [markdown]
# ### nltk 불용어(stopwords) 패키지 이용하기

# %%
import nltk
nltk.download('stopwords')

import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='bs4')

print('=3')
# Out:
# [nltk_data] Downloading package stopwords to /aiffel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# =3

# %% [markdown]
# ### 데이터 불러오기
# 전체 568,454개 데이터 중 10만개만 가져오기

# %%
data = pd.read_csv(os.getenv("HOME")+"/aiffel/news_summarization/data/Reviews.csv", nrows=100000)
print('전체 샘플수 :', (len(data)))

data.head()
# Out:
# 전체 샘플수 : 100000
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ### Test, Summary열만 가져와 데이터 새로 구성

# %%
data = data[['Text','Summary']]
data.head()

#랜덤한 15개 샘플 출력
data.sample(15)
# Out:
#                                                     Text  \
# 32139  The Yogi's Black Chai is the best and closest ...
# 28779  These wasabi peas are very good in my opinion....
# 87553  Sweet and tasty popcorn delivered to your door...
# 12191  I'm disturbed that these treats, as many revie...
# 10988  I love the litter dropper in the lid to add ju...
# 42745  This grape juice has a very strong tasting gra...
# 5886   I eat them just like this!  I like something w...
# 11759  My kids loves Chips Ahoy! and I will have them...
# 77463  Their the perfect treat for my service dog. I ...
# 47958  Quick and easy! Buying on here is so much easi...
# 23217  This is pretty decent coffee. Not the best, bu...
# 77830  Switch Black Cherry soda had sort of a strange...
# 96649  Okay -she is a Shih Tzu----even still this is ...
# 64266  Like many, I have drank tea for many years, de...
# 10317  I'm so glad these are finally available again....
#
#                                                  Summary
# 32139                                    Best Tea by far
# 28779                   very good but I have 1 complaint
# 87553                          How could this be bad....
# 12191                             BEWARE:  MADE IN CHINA
# 10988                    Excellent for Spicing up Dishes
# 42745                Quite different to the other brands
# 5886                                        Great snack!
# 11759                       There's something wrong here
# 77463                            Tuff Pet Treats Chicken
# 47958                                  I love this stuff
# 23217                                             Decent
# 77830                                     Okay not great
# 96649                         Last for days - weeks  LOL
# 64266  Outstanding Tea for Connoisseur or Non-Connois...
# 10317                               Microwave pork rinds

# %% [markdown]
# ### 데이터 전처리 - 중복값, 결측값 제거

# %% [markdown]
# summary에서는 중복값이 나올수 있다. 다른 문장도 같게 요약할 수 있기 때문이다. 하지만 텍스트 중복값은 삭제해 줘야한다.

# %%
# 중복값 제거
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['Text'].nunique())
print('Summary 열에서 중복을 배제한 유일한 샘플의 수 :', data['Summary'].nunique())

# inplace=True 를 설정하면 DataFrame 타입 값을 return 하지 않고 data 내부를 직접적으로 바꿉니다
data.drop_duplicates(subset = ['Text'], inplace=True) #중복값 삭제
print('전체 샘플수 :', (len(data)))
# Out:
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 88426
# Summary 열에서 중복을 배제한 유일한 샘플의 수 : 72348
# 전체 샘플수 : 88426

# %%
#결측값 제거
print(data.isnull().sum())

data.dropna(axis=0, inplace=True) #결측값 삭제
print('전체 샘플수 :', (len(data)))
# Out:
# Text       0
# Summary    1
# dtype: int64
# 전체 샘플수 : 88425

# %% [markdown]
# ### 텍스트 정규화 + 불용어 제거
#
#
# ##### Text normalization?(텍스트 정규화)
# it'll은 it will과 같고, mustn't과 must not은 사실 같은 표현이다. 이런 경우 기계가 굳이 이들을 마치 다른 단어로 간주하게 해서 연산량을 늘리는 것보다는 기계 학습 전에 미리 같은 표현으로 통일시켜주는 것이 기계의 연산량을 줄일 수 있다. 이를 텍스트 정규화라고 한다.

# %%
#정규화 사전 만들기
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %% [markdown]
# ##### Stopwords?(불용어)
# 텍스트에는 자주 등장하지만 자연어 처리를 할 때 실질적으로는 별 도움이 안되는 단어들

# %%
#불용어 사진 확인
print('불용어 개수 :', len(stopwords.words('english') ))
print(stopwords.words('english'))
# Out:
# 불용어 개수 : 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# ### 그 외 전처리
# - 모든 영어 문자는 소문자로 수정
# - 섞여있는 html 태그를 제거
# - 정규 표현식을 통해 각종 특수문자를 제거
#
#
# - 불용어는 text에서만 제거, summary에는 불용어가 있는게 자연스러울 것으로 예상

# %%
# 데이터 전처리 함수
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","", sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah
    
    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # 불용어 미제거 (Summary)
    else: #if remove_stopwords = False
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens
print('=3')
# Out:
# =3

# %%
#함수 작동 확인
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_summary = 'Great way to start (or finish) the day!!!'

print("text: ", preprocess_sentence(temp_text))
print("summary:", preprocess_sentence(temp_summary, False))  # 불용어를 제거하지 않습니다.
# Out:
# text:  everything bought great infact ordered twice third ordered wasfor mother father
# summary: great way to start the day

# %% [markdown]
# ### 데이터 전처리 함수에 넣고 돌리기

# %%
clean_text = []
# 전체 Text 데이터에 대한 전처리 : 10분 이상 시간이 걸릴 수 있습니다. 
for s in data['Text']:
    clean_text.append(preprocess_sentence(s))

# 전처리 후 출력
print("Text 전처리 후 결과: ", clean_text[:5])
# Out:
# Text 전처리 후 결과:  ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better', 'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo', 'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch', 'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal', 'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %% [markdown]
#  Summary에 대해서 전처리 함수를 호출해 줄 때는, 불용어 제거를 수행하지 않는다는 의미에서 두 번째 인자로 False 삽입

# %%
clean_summary = []
# 전체 Summary 데이터에 대한 전처리 : 5분 이상 시간이 걸릴 수 있습니다. 
for s in data['Summary']:
    clean_summary.append(preprocess_sentence(s, False))

print("Summary 전처리 후 결과: ", clean_summary[:5])
# Out:
# Summary 전처리 후 결과:  ['good quality dog food', 'not as advertised', 'delight says it all', 'cough medicine', 'great taffy']

# %% [markdown]
# 더 보기 좋게 하기 위해 dataFrame에 저장
#
# - 빈 값은 null 값으로 변환

# %%
data['Text'] = clean_text
data['Summary'] = clean_summary

# 빈 값을 Null 값으로 변환
data.replace('', np.nan, inplace=True)
print('=3')
# Out:
# =3

# %% [markdown]
# null값이 생겼는지 확인

# %%
data.isnull().sum()
# Out:
# Text        0
# Summary    70
# dtype: int64

# %% [markdown]
# - Summary 열에서 70개의 Null 값 발생. 원래는 단어가 있었는데, 정제 과정에서 모든 단어가 제거되어 빈 샘플이 70개나 생겼다는 의미.

# %% [markdown]
# summary에 null값 생긴 데이터 삭제

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 88355

# %% [markdown]
# ### 샘플 최대 길이 구하기
# Text와 Summary의 최소, 최대, 평균 길이를 구하고 또한 길이 분포를 시각화

# %%
# 길이 분포 출력
import matplotlib.pyplot as plt

text_len = [len(s.split()) for s in data['Text']]
summary_len = [len(s.split()) for s in data['Summary']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(text_len)
plt.title('Text')
plt.subplot(1,2,2)
plt.boxplot(summary_len)
plt.title('Summary')
plt.tight_layout()
plt.show()

plt.title('Text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Summary')
plt.hist(summary_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 2
# 텍스트의 최대 길이 : 1235
# 텍스트의 평균 길이 : 38.792428272310566
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 28
# 요약의 평균 길이 : 4.010729443721352

# %% [markdown]
# 최솟값과 최댓값의 차이가 굉장히 큰데, Text의 경우 길이 100 내외, Summary의 경우 10 내외에 대부분의 데이터가 분포해 있다.

# %% [markdown]
# ####  Text의 최대 길이와 Summary의 적절한 최대 길이를 임의로 지정

# %%
text_max_len = 80
summary_max_len = 8
print('=3')
# Out:
# =3

# %% [markdown]
# 자른 길이로 데이터를 얼마나 가져올 수 있는지 파악

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s.split()) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))
print('=3')
# Out:
# =3

# %% [markdown]
# 데이터 가져오는 양 비율 확인

# %%
below_threshold_len(text_max_len, data['Text'])
below_threshold_len(summary_max_len,  data['Summary'])
# Out:
# 전체 샘플 중 길이가 80 이하인 샘플의 비율: 0.9076679305076113
# 전체 샘플 중 길이가 8 이하인 샘플의 비율: 0.9424593967517402

# %% [markdown]
# #### 정해진 길이보다 긴 데이터 삭제

# %%
data = data[data['Text'].apply(lambda x: len(x.split()) <= text_max_len)]
data = data[data['Summary'].apply(lambda x: len(x.split()) <= summary_max_len)]
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 76469

# %% [markdown]
# data.apply(function_name) 함수는 data 해당 부분에 function_name을 적용하는 함수

# %%
data.head()
# Out:
#                                                 Text                Summary
# 0  bought several vitality canned dog food produc...  good quality dog food
# 1  product arrived labeled jumbo salted peanuts p...      not as advertised
# 2  confection around centuries light pillowy citr...    delight says it all
# 3  looking secret ingredient robitussin believe f...         cough medicine
# 4  great taffy great price wide assortment yummy ...            great taffy

# %% [markdown]
# ### 시작토큰 & 종료토큰 삽입하기
# 디코더는 시작 토큰을 입력받아 문장을 생성하기 시작하고, 종료 토큰을 예측한 순간에 문장 생성을 멈추는 방식
#
# - 시작 토큰은 sostoken, 종료 토큰은 eostoken이라 임의로 명명하고 앞, 뒤로 추가
#
#
# - 디코더의 입력에 해당하면서 시작 토큰이 맨 앞에 있는 문장의 이름을 decoder_input, 디코더의 출력 또는 레이블에 해당되면서 종료 토큰이 맨 뒤에 붙는 문장의 이름을 decoder_target

# %%
# 요약 데이터에는 시작 토큰과 종료 토큰을 추가한다.
data['decoder_input'] = data['Summary'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['Summary'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                                                 Text                Summary  \
# 0  bought several vitality canned dog food produc...  good quality dog food
# 1  product arrived labeled jumbo salted peanuts p...      not as advertised
# 2  confection around centuries light pillowy citr...    delight says it all
# 3  looking secret ingredient robitussin believe f...         cough medicine
# 4  great taffy great price wide assortment yummy ...            great taffy
#
#                     decoder_input                  decoder_target
# 0  sostoken good quality dog food  good quality dog food eostoken
# 1      sostoken not as advertised      not as advertised eostoken
# 2    sostoken delight says it all    delight says it all eostoken
# 3         sostoken cough medicine         cough medicine eostoken
# 4            sostoken great taffy            great taffy eostoken

# %% [markdown]
#  인코더의 입력, 디코더의 입력과 레이블을 각각 다시 Numpy 타입으로 저장

# %%
encoder_input = np.array(data['Text']) # 인코더의 입력
decoder_input = np.array(data['decoder_input']) # 디코더의 입력
decoder_target = np.array(data['decoder_target']) # 디코더의 레이블
print('=3')
# Out:
# =3

# %% [markdown]
# ### 훈련데이터 & 평가데이터로 분리
# 직접 코딩해 변경하기

# %%
#encoder_input과 크기와 형태가 같은 순서가 섞인 정수 시퀸스 만듦
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)

#이렇게 만든 정수 시퀸스를 이용해 랜덤으로 데이터 샘플순서 섞기
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

#데이터 8:2비율로 훈련셋, 평가셋 분리
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :', n_of_val)

#테스트 갯수 이용해 전테 데이터 양분
#
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# [75976 69168 75881 ... 73327 38618 50630]
# 테스트 데이터의 수 : 15293
# 훈련 데이터의 개수 : 61176
# 훈련 레이블의 개수 : 61176
# 테스트 데이터의 개수 : 15293
# 테스트 레이블의 개수 : 15293

# %% [markdown]
# ### 단어 집합 만들기 및 정수 인코딩
#
# #### 단어 집합(vocabulary)?
# - 기계가 텍스트를 숫자로 처리할 수 있도록 훈련 데이터와 테스트 데이터의 단어들을 모두 정수로 바꾸는 것. (각 단어에 고유한 정수를 맵핑)
#
# 원문에 해당되는 encoder_input_train에 대해서 단어 집합 생성

# %% [markdown]
# ###  encoder_input_train 처리하기(Text data)
#
# #### 토크나이저 가져오고 encoder_input_train 데이터 넣기

# %%
src_tokenizer = Tokenizer() # 토크나이저 정의
src_tokenizer.fit_on_texts(encoder_input_train) # 입력된 데이터로부터 단어 집합 생성
print('=3')
# Out:
# =3

# %% [markdown]
# 현재 생성된 단어 집합은 src_tokenizer.word_index에 저장

# %%
src_tokenizer.word_index
# Out:
# {'like': 1,
#  'good': 2,
#  'great': 3,
#  'taste': 4,
#  'one': 5,
#  'product': 6,
#  'would': 7,
#  'flavor': 8,
#  'coffee': 9,
#  'love': 10,
#  'tea': 11,
#  'really': 12,
#  'get': 13,
#  'food': 14,
#  'amazon': 15,
#  'much': 16,
#  'price': 17,
#  'buy': 18,
#  'best': 19,
#  'little': 20,
#  'time': 21,
#  'use': 22,
#  'tried': 23,
#  'also': 24,
#  'find': 25,
#  'better': 26,
#  'make': 27,
#  'well': 28,
#  'chocolate': 29,
#  'try': 30,
#  'dog': 31,
#  'even': 32,
#  'eat': 33,
#  'drink': 34,
#  'could': 35,
#  'bought': 36,
#  'found': 37,
#  'first': 38,
#  'bag': 39,
#  'sweet': 40,
#  'sugar': 41,
#  'cup': 42,
#  'used': 43,
#  'tastes': 44,
#  'order': 45,
#  'delicious': 46,
#  'made': 47,
#  'recommend': 48,
#  'store': 49,
#  'cannot': 50,
#  'free': 51,
#  'box': 52,
#  'way': 53,
#  'water': 54,
#  'nice': 55,
#  'go': 56,
#  'favorite': 57,
#  'think': 58,
#  'loves': 59,
#  'two': 60,
#  'bit': 61,
#  'since': 62,
#  'got': 63,
#  'day': 64,
#  'give': 65,
#  'still': 66,
#  'mix': 67,
#  'hot': 68,
#  'flavors': 69,
#  'dogs': 70,
#  'many': 71,
#  'never': 72,
#  'every': 73,
#  'know': 74,
#  'easy': 75,
#  'perfect': 76,
#  'snack': 77,
#  'ordered': 78,
#  'makes': 79,
#  'treats': 80,
#  'brand': 81,
#  'something': 82,
#  'without': 83,
#  'ever': 84,
#  'right': 85,
#  'stuff': 86,
#  'always': 87,
#  'want': 88,
#  'lot': 89,
#  'quality': 90,
#  'add': 91,
#  'healthy': 92,
#  'years': 93,
#  'fresh': 94,
#  'milk': 95,
#  'keep': 96,
#  'say': 97,
#  'small': 98,
#  'enough': 99,
#  'strong': 100,
#  'old': 101,
#  'definitely': 102,
#  'hard': 103,
#  'less': 104,
#  'however': 105,
#  'different': 106,
#  'enjoy': 107,
#  'tasty': 108,
#  'bad': 109,
#  'buying': 110,
#  'treat': 111,
#  'organic': 112,
#  'sure': 113,
#  'need': 114,
#  'chips': 115,
#  'local': 116,
#  'back': 117,
#  'eating': 118,
#  'happy': 119,
#  'products': 120,
#  'thought': 121,
#  'regular': 122,
#  'put': 123,
#  'salt': 124,
#  'though': 125,
#  'long': 126,
#  'looking': 127,
#  'far': 128,
#  'ingredients': 129,
#  'pretty': 130,
#  'whole': 131,
#  'size': 132,
#  'using': 133,
#  'shipping': 134,
#  'wonderful': 135,
#  'highly': 136,
#  'purchase': 137,
#  'high': 138,
#  'excellent': 139,
#  'tasted': 140,
#  'pack': 141,
#  'bags': 142,
#  'work': 143,
#  'thing': 144,
#  'package': 145,
#  'big': 146,
#  'sauce': 147,
#  'cups': 148,
#  'bars': 149,
#  'tasting': 150,
#  'purchased': 151,
#  'texture': 152,
#  'green': 153,
#  'quite': 154,
#  'going': 155,
#  'low': 156,
#  'see': 157,
#  'actually': 158,
#  'last': 159,
#  'cookies': 160,
#  'stores': 161,
#  'worth': 162,
#  'natural': 163,
#  'year': 164,
#  'chicken': 165,
#  'cat': 166,
#  'take': 167,
#  'loved': 168,
#  'calories': 169,
#  'family': 170,
#  'real': 171,
#  'oil': 172,
#  'rice': 173,
#  'grocery': 174,
#  'almost': 175,
#  'gluten': 176,
#  'anything': 177,
#  'feel': 178,
#  'dark': 179,
#  'another': 180,
#  'people': 181,
#  'new': 182,
#  'received': 183,
#  'came': 184,
#  'arrived': 185,
#  'popcorn': 186,
#  'expensive': 187,
#  'full': 188,
#  'smell': 189,
#  'may': 190,
#  'trying': 191,
#  'around': 192,
#  'half': 193,
#  'getting': 194,
#  'cereal': 195,
#  'fruit': 196,
#  'coconut': 197,
#  'butter': 198,
#  'added': 199,
#  'diet': 200,
#  'item': 201,
#  'several': 202,
#  'candy': 203,
#  'bar': 204,
#  'away': 205,
#  'home': 206,
#  'fat': 207,
#  'brands': 208,
#  'foods': 209,
#  'blend': 210,
#  'usually': 211,
#  'husband': 212,
#  'oz': 213,
#  'amount': 214,
#  'cheese': 215,
#  'morning': 216,
#  'probably': 217,
#  'said': 218,
#  'per': 219,
#  'money': 220,
#  'juice': 221,
#  'dry': 222,
#  'disappointed': 223,
#  'kids': 224,
#  'us': 225,
#  'problem': 226,
#  'come': 227,
#  'case': 228,
#  'absolutely': 229,
#  'reviews': 230,
#  'days': 231,
#  'liked': 232,
#  'bottle': 233,
#  'black': 234,
#  'things': 235,
#  'seems': 236,
#  'available': 237,
#  'bitter': 238,
#  'nothing': 239,
#  'able': 240,
#  'wish': 241,
#  'cats': 242,
#  'months': 243,
#  'company': 244,
#  'kind': 245,
#  'flavored': 246,
#  'honey': 247,
#  'smooth': 248,
#  'energy': 249,
#  'light': 250,
#  'ones': 251,
#  'deal': 252,
#  'making': 253,
#  'drinking': 254,
#  'comes': 255,
#  'fine': 256,
#  'large': 257,
#  'especially': 258,
#  'protein': 259,
#  'might': 260,
#  'fast': 261,
#  'breakfast': 262,
#  'works': 263,
#  'variety': 264,
#  'instead': 265,
#  'packaging': 266,
#  'pasta': 267,
#  'look': 268,
#  'boxes': 269,
#  'gave': 270,
#  'top': 271,
#  'ginger': 272,
#  'save': 273,
#  'three': 274,
#  'bread': 275,
#  'quickly': 276,
#  'others': 277,
#  'quick': 278,
#  'peanut': 279,
#  'meal': 280,
#  'ordering': 281,
#  'cheaper': 282,
#  'maybe': 283,
#  'prefer': 284,
#  'stars': 285,
#  'house': 286,
#  'syrup': 287,
#  'rich': 288,
#  'either': 289,
#  'spicy': 290,
#  'cans': 291,
#  'recommended': 292,
#  'roast': 293,
#  'health': 294,
#  'beans': 295,
#  'fact': 296,
#  'seem': 297,
#  'extra': 298,
#  'times': 299,
#  'next': 300,
#  'wanted': 301,
#  'cream': 302,
#  'pieces': 303,
#  'vanilla': 304,
#  'decided': 305,
#  'gift': 306,
#  'glad': 307,
#  'least': 308,
#  'son': 309,
#  'went': 310,
#  'soft': 311,
#  'fan': 312,
#  'anyone': 313,
#  'review': 314,
#  'amazing': 315,
#  'month': 316,
#  'must': 317,
#  'teas': 318,
#  'couple': 319,
#  'ago': 320,
#  'baby': 321,
#  'nuts': 322,
#  'white': 323,
#  'cost': 324,
#  'everyone': 325,
#  'likes': 326,
#  'open': 327,
#  'started': 328,
#  'plastic': 329,
#  'else': 330,
#  'corn': 331,
#  'plus': 332,
#  'took': 333,
#  'everything': 334,
#  'yet': 335,
#  'teeth': 336,
#  'noodles': 337,
#  'crunchy': 338,
#  'keurig': 339,
#  'longer': 340,
#  'salty': 341,
#  'daughter': 342,
#  'minutes': 343,
#  'although': 344,
#  'super': 345,
#  'rather': 346,
#  'enjoyed': 347,
#  'yummy': 348,
#  'let': 349,
#  'lemon': 350,
#  'value': 351,
#  'soup': 352,
#  'read': 353,
#  'thank': 354,
#  'friends': 355,
#  'market': 356,
#  'ice': 357,
#  'thanks': 358,
#  'mouth': 359,
#  'soda': 360,
#  'week': 361,
#  'ounce': 362,
#  'drinks': 363,
#  'cold': 364,
#  'help': 365,
#  'awesome': 366,
#  'pepper': 367,
#  'online': 368,
#  'cocoa': 369,
#  'alternative': 370,
#  'chew': 371,
#  'ok': 372,
#  'powder': 373,
#  'bold': 374,
#  'cookie': 375,
#  'second': 376,
#  'beef': 377,
#  'says': 378,
#  'part': 379,
#  'pleased': 380,
#  'serving': 381,
#  'sometimes': 382,
#  'opened': 383,
#  'mixed': 384,
#  'expected': 385,
#  'type': 386,
#  'jerky': 387,
#  'version': 388,
#  'smaller': 389,
#  'side': 390,
#  'meat': 391,
#  'wheat': 392,
#  'gets': 393,
#  'goes': 394,
#  'machine': 395,
#  'weight': 396,
#  'red': 397,
#  'dried': 398,
#  'snacks': 399,
#  'surprised': 400,
#  'believe': 401,
#  'difference': 402,
#  'easily': 403,
#  'special': 404,
#  'crackers': 405,
#  'cook': 406,
#  'cooking': 407,
#  'french': 408,
#  'exactly': 409,
#  'wrong': 410,
#  'left': 411,
#  'flavorful': 412,
#  'orange': 413,
#  'tell': 414,
#  'plain': 415,
#  'etc': 416,
#  'aftertaste': 417,
#  'wife': 418,
#  'clean': 419,
#  'container': 420,
#  'hand': 421,
#  'reason': 422,
#  'slightly': 423,
#  'often': 424,
#  'recently': 425,
#  'brown': 426,
#  'giving': 427,
#  'end': 428,
#  'choice': 429,
#  'guess': 430,
#  'recipe': 431,
#  'overall': 432,
#  'problems': 433,
#  'aroma': 434,
#  'artificial': 435,
#  'place': 436,
#  'service': 437,
#  'oatmeal': 438,
#  'dinner': 439,
#  'granola': 440,
#  'packaged': 441,
#  'delivery': 442,
#  'cherry': 443,
#  'picky': 444,
#  'line': 445,
#  'friend': 446,
#  'care': 447,
#  'decaf': 448,
#  'weeks': 449,
#  'cut': 450,
#  'subscribe': 451,
#  'seeds': 452,
#  'smells': 453,
#  'bite': 454,
#  'packs': 455,
#  'run': 456,
#  'canned': 457,
#  'almonds': 458,
#  'convenient': 459,
#  'bulk': 460,
#  'mild': 461,
#  'compared': 462,
#  'huge': 463,
#  'life': 464,
#  'bottles': 465,
#  'pay': 466,
#  'fantastic': 467,
#  'potato': 468,
#  'iced': 469,
#  'live': 470,
#  'shipped': 471,
#  'stick': 472,
#  'original': 473,
#  'brew': 474,
#  'toy': 475,
#  'looked': 476,
#  'looks': 477,
#  'hair': 478,
#  'stomach': 479,
#  'spice': 480,
#  'coffees': 481,
#  'continue': 482,
#  'pop': 483,
#  'filling': 484,
#  'ate': 485,
#  'apple': 486,
#  'saw': 487,
#  'night': 488,
#  'cake': 489,
#  'needed': 490,
#  'refreshing': 491,
#  'start': 492,
#  'unfortunately': 493,
#  'simply': 494,
#  'feed': 495,
#  'excited': 496,
#  'close': 497,
#  'chewy': 498,
#  'similar': 499,
#  'cinnamon': 500,
#  'someone': 501,
#  'fiber': 502,
#  'espresso': 503,
#  'gives': 504,
#  'lots': 505,
#  'packages': 506,
#  'calorie': 507,
#  'past': 508,
#  'larger': 509,
#  'finally': 510,
#  'healthier': 511,
#  'four': 512,
#  'sent': 513,
#  'chai': 514,
#  'gum': 515,
#  'eaten': 516,
#  'date': 517,
#  'already': 518,
#  'color': 519,
#  'soon': 520,
#  'course': 521,
#  'christmas': 522,
#  'hope': 523,
#  'starbucks': 524,
#  'lunch': 525,
#  'com': 526,
#  'idea': 527,
#  'chip': 528,
#  'caffeine': 529,
#  'hours': 530,
#  'olive': 531,
#  'pound': 532,
#  'bowl': 533,
#  'sweetness': 534,
#  'heat': 535,
#  'seasoning': 536,
#  'expect': 537,
#  'seller': 538,
#  'inside': 539,
#  'along': 540,
#  'star': 541,
#  'creamy': 542,
#  'nut': 543,
#  'single': 544,
#  'needs': 545,
#  'non': 546,
#  'sodium': 547,
#  'gone': 548,
#  'given': 549,
#  'adding': 550,
#  'experience': 551,
#  'jar': 552,
#  'mine': 553,
#  'broken': 554,
#  'extremely': 555,
#  'microwave': 556,
#  'carry': 557,
#  'due': 558,
#  'stock': 559,
#  'delivered': 560,
#  'change': 561,
#  'soy': 562,
#  'takes': 563,
#  'purchasing': 564,
#  'helps': 565,
#  'items': 566,
#  'salad': 567,
#  'sold': 568,
#  'please': 569,
#  'cheap': 570,
#  'mind': 571,
#  'pet': 572,
#  'wait': 573,
#  'daily': 574,
#  'crunch': 575,
#  'done': 576,
#  'formula': 577,
#  'packet': 578,
#  'ground': 579,
#  'completely': 580,
#  'rest': 581,
#  'certainly': 582,
#  'leave': 583,
#  'ingredient': 584,
#  'waste': 585,
#  'stale': 586,
#  'within': 587,
#  'vet': 588,
#  'fish': 589,
#  'together': 590,
#  'list': 591,
#  'weak': 592,
#  'packed': 593,
#  'keeps': 594,
#  'flour': 595,
#  'based': 596,
#  'bottom': 597,
#  'yes': 598,
#  'sour': 599,
#  'consistency': 600,
#  'baking': 601,
#  'thick': 602,
#  'grain': 603,
#  'switch': 604,
#  'seemed': 605,
#  'leaves': 606,
#  'difficult': 607,
#  'stop': 608,
#  'five': 609,
#  'name': 610,
#  'raw': 611,
#  'medium': 612,
#  'hit': 613,
#  'shipment': 614,
#  'opinion': 615,
#  'packets': 616,
#  'pumpkin': 617,
#  'noticed': 618,
#  'pot': 619,
#  'instant': 620,
#  'true': 621,
#  'dish': 622,
#  'worked': 623,
#  'lb': 624,
#  'contains': 625,
#  'pick': 626,
#  'break': 627,
#  'later': 628,
#  'content': 629,
#  'condition': 630,
#  'pork': 631,
#  'hour': 632,
#  'chili': 633,
#  'entire': 634,
#  'locally': 635,
#  'yogurt': 636,
#  'sale': 637,
#  'easier': 638,
#  'normally': 639,
#  'almond': 640,
#  'today': 641,
#  'totally': 642,
#  'simple': 643,
#  'newman': 644,
#  'maker': 645,
#  'okay': 646,
#  'mint': 647,
#  'puppy': 648,
#  'pure': 649,
#  'discovered': 650,
#  'become': 651,
#  'bland': 652,
#  'throw': 653,
#  'label': 654,
#  'satisfying': 655,
#  'batch': 656,
#  'expecting': 657,
#  'wow': 658,
#  'perfectly': 659,
#  'lower': 660,
#  'cooked': 661,
#  'baked': 662,
#  'eats': 663,
#  'training': 664,
#  'beat': 665,
#  'truly': 666,
#  'anyway': 667,
#  'addition': 668,
#  'hooked': 669,
#  'reasonable': 670,
#  'unless': 671,
#  'normal': 672,
#  'issues': 673,
#  'fun': 674,
#  'decent': 675,
#  'anywhere': 676,
#  'stopped': 677,
#  'crazy': 678,
#  'tiny': 679,
#  'kick': 680,
#  'area': 681,
#  'blue': 682,
#  'strawberry': 683,
#  'hint': 684,
#  'moist': 685,
#  'varieties': 686,
#  'substitute': 687,
#  'combination': 688,
#  'recipes': 689,
#  'stay': 690,
#  'oh': 691,
#  'remember': 692,
#  'glass': 693,
#  'beverage': 694,
#  'count': 695,
#  'world': 696,
#  'customer': 697,
#  'twice': 698,
#  'shop': 699,
#  'sell': 700,
#  'acid': 701,
#  'none': 702,
#  'future': 703,
#  'told': 704,
#  'spices': 705,
#  'particular': 706,
#  'pleasant': 707,
#  'finish': 708,
#  'summer': 709,
#  'option': 710,
#  'finding': 711,
#  'anymore': 712,
#  'banana': 713,
#  'called': 714,
#  'felt': 715,
#  'shake': 716,
#  'mess': 717,
#  'chews': 718,
#  'six': 719,
#  'warm': 720,
#  'plan': 721,
#  'loose': 722,
#  'point': 723,
#  'seen': 724,
#  'yum': 725,
#  'roasted': 726,
#  'horrible': 727,
#  'piece': 728,
#  'sweetener': 729,
#  'description': 730,
#  'favorites': 731,
#  'pricey': 732,
#  'carb': 733,
#  'feeling': 734,
#  'forward': 735,
#  'maple': 736,
#  'contain': 737,
#  'licorice': 738,
#  'turned': 739,
#  'body': 740,
#  'thin': 741,
#  'immediately': 742,
#  'touch': 743,
#  'hoping': 744,
#  'somewhat': 745,
#  'dont': 746,
#  'greenies': 747,
#  'mixes': 748,
#  'satisfied': 749,
#  'meals': 750,
#  'feeding': 751,
#  'otherwise': 752,
#  'pie': 753,
#  'liquid': 754,
#  'grams': 755,
#  'impressed': 756,
#  'grey': 757,
#  'overly': 758,
#  'awful': 759,
#  'terrible': 760,
#  'bean': 761,
#  'reading': 762,
#  'mom': 763,
#  'prices': 764,
#  'return': 765,
#  'ready': 766,
#  'taking': 767,
#  'stronger': 768,
#  'veggies': 769,
#  'garlic': 770,
#  'priced': 771,
#  'drinker': 772,
#  'thinking': 773,
#  'stevia': 774,
#  'chewing': 775,
#  'caramel': 776,
#  'nutrition': 777,
#  'results': 778,
#  'fit': 779,
#  'supermarket': 780,
#  'serve': 781,
#  'vinegar': 782,
#  'style': 783,
#  'adds': 784,
#  'door': 785,
#  'costco': 786,
#  'person': 787,
#  'skin': 788,
#  'fairly': 789,
#  'unlike': 790,
#  'check': 791,
#  'note': 792,
#  'mostly': 793,
#  'means': 794,
#  'perhaps': 795,
#  'balance': 796,
#  'job': 797,
#  'sort': 798,
#  'uses': 799,
#  'paid': 800,
#  'agree': 801,
#  'clear': 802,
#  'peanuts': 803,
#  'pancakes': 804,
#  'nearly': 805,
#  'heavy': 806,
#  'benefits': 807,
#  'homemade': 808,
#  'berry': 809,
#  'carbs': 810,
#  'earl': 811,
#  'matter': 812,
#  'italian': 813,
#  'allergies': 814,
#  'sealed': 815,
#  'individual': 816,
#  'changed': 817,
#  'pods': 818,
#  'salmon': 819,
#  'reviewer': 820,
#  'plenty': 821,
#  'set': 822,
#  'nicely': 823,
#  'mountain': 824,
#  'kitchen': 825,
#  'bring': 826,
#  'short': 827,
#  'complaint': 828,
#  'subscription': 829,
#  'except': 830,
#  'flavoring': 831,
#  'everyday': 832,
#  'sea': 833,
#  'pouch': 834,
#  'call': 835,
#  'chocolates': 836,
#  'afternoon': 837,
#  'shape': 838,
#  'issue': 839,
#  'notice': 840,
#  'convenience': 841,
#  'higher': 842,
#  'overpowering': 843,
#  'bake': 844,
#  'hate': 845,
#  'sick': 846,
#  'brewed': 847,
#  'reviewers': 848,
#  'supposed': 849,
#  'candies': 850,
#  'crisp': 851,
#  'supply': 852,
#  'hands': 853,
#  'ask': 854,
#  'lime': 855,
#  'knew': 856,
#  'office': 857,
#  'directions': 858,
#  'sample': 859,
#  'near': 860,
#  'wrapped': 861,
#  'gourmet': 862,
#  'standard': 863,
#  'bits': 864,
#  'carbonated': 865,
#  'whatever': 866,
#  'source': 867,
#  'picture': 868,
#  'pour': 869,
#  'kept': 870,
#  'thrilled': 871,
#  'expiration': 872,
#  'craving': 873,
#  'bones': 874,
#  'bears': 875,
#  'brewing': 876,
#  'tree': 877,
#  'mother': 878,
#  'chance': 879,
#  'personally': 880,
#  'usual': 881,
#  'ended': 882,
#  'party': 883,
#  'prepare': 884,
#  'bbq': 885,
#  'replacement': 886,
#  'weird': 887,
#  'sweetened': 888,
#  'sitting': 889,
#  'running': 890,
#  'shampoo': 891,
#  'served': 892,
#  'mango': 893,
#  'ship': 894,
#  'vegetables': 895,
#  'cause': 896,
#  'dented': 897,
#  'dishes': 898,
#  'lover': 899,
#  'brought': 900,
#  'coming': 901,
#  'raspberry': 902,
#  'crispy': 903,
#  'fill': 904,
#  'grains': 905,
#  'send': 906,
#  'china': 907,
#  'number': 908,
#  'jelly': 909,
#  'worst': 910,
#  'carrying': 911,
#  'lbs': 912,
#  'gotten': 913,
#  'breath': 914,
#  'plant': 915,
#  'bigger': 916,
#  'cashews': 917,
#  'share': 918,
#  'alone': 919,
#  'including': 920,
#  'stuck': 921,
#  'website': 922,
#  'straight': 923,
#  'outside': 924,
#  'children': 925,
#  'sorry': 926,
#  'blood': 927,
#  'eggs': 928,
#  'pizza': 929,
#  'sticks': 930,
#  'imagine': 931,
#  'kid': 932,
#  'biscuits': 933,
#  'types': 934,
#  'consider': 935,
#  'hold': 936,
#  'putting': 937,
#  'cracker': 938,
#  'working': 939,
#  'shelf': 940,
#  'air': 941,
#  'traditional': 942,
#  'sauces': 943,
#  'sensitive': 944,
#  'trouble': 945,
#  'opening': 946,
#  'offer': 947,
#  'vegan': 948,
#  'instructions': 949,
#  'chunks': 950,
#  'wine': 951,
#  'unique': 952,
#  'ounces': 953,
#  'broccoli': 954,
#  'avoid': 955,
#  'heard': 956,
#  'fridge': 957,
#  'restaurant': 958,
#  'surprise': 959,
#  'turkey': 960,
#  'portion': 961,
#  'tend': 962,
#  'gf': 963,
#  'suggest': 964,
#  'pleasantly': 965,
#  'helped': 966,
#  'switched': 967,
#  'turn': 968,
#  'double': 969,
#  'pantry': 970,
#  'offered': 971,
#  'soups': 972,
#  'slight': 973,
#  'listed': 974,
#  'subtle': 975,
#  'eater': 976,
#  'figured': 977,
#  'dressing': 978,
#  'compare': 979,
#  'whenever': 980,
#  'jars': 981,
#  'kinds': 982,
#  'actual': 983,
#  'sized': 984,
#  'beautiful': 985,
#  'across': 986,
#  'addicted': 987,
#  'tomato': 988,
#  'paying': 989,
#  'pounds': 990,
#  'fair': 991,
#  'stash': 992,
#  'nutritional': 993,
#  'covered': 994,
#  'tart': 995,
#  'mean': 996,
#  'tuna': 997,
#  'quantity': 998,
#  'busy': 999,
#  'boost': 1000,
#  ...}

# %% [markdown]
# ### 빈도수가 낮은 단어들은 훈련 데이터에서 제외하고 진행
#
# src_tokenizer.word_counts.items()에는 단어와 각 단어의 등장 빈도수가 저장,
# 이를 통해서 통계적인 정보를 얻기 가능

# %%
len(src_tokenizer.word_counts.items())
# Out:
# 38477

# %% [markdown]
# 등장 빈도수가 7회 미만인 단어들이 이 데이터에서 얼만큼의 비중을 차지하는지 확인

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 38477
# 등장 빈도가 6번 이하인 희귀 단어의 수: 28349
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 10128
# 단어 집합에서 희귀 단어의 비율: 73.67778153182421
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 2.8313697225071386

# %% [markdown]
# 등장 빈도가 6회 이하인 단어들은 정수 인코딩 과정에서 빼고, 훈련 데이터에서 제거
#
# 위에서 이를 제외한 단어 집합의 크기를 1만여 개로 계산했는데, 이와 비슷한 값으로 어림잡아 단어 집합의 크기를 10,000으로 제한

# %%
src_vocab = 10000
src_tokenizer = Tokenizer(num_words=src_vocab) # 단어 집합의 크기를 10,000으로 제한
src_tokenizer.fit_on_texts(encoder_input_train) # 단어 집합 재생성
print('=3')
# Out:
# =3

# %% [markdown]
# ### texts_to_sequences() 이용 정수 인코딩
#
# 생성된 단어 집합에 기반하여 입력으로 주어진 텍스트 데이터의 단어들을 모두 정수로 변환하는 정수 인코딩을 수행
#
# 현재 단어 집합의 크기를 8,000으로 제한했으니까 이제 10,000이 넘는 숫자들은 정수 인코딩 후에는 데이터에 존재 X

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train) 
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# 잘 진행되었는지 샘플 출력
print(encoder_input_train[:3])
# Out:
# [[10, 438, 112, 2, 219, 52, 7276, 2287, 7, 466, 274, 269, 265, 2099, 17, 82], [425, 2764, 2040, 5794, 473, 31, 14, 70, 180, 314, 6325, 192, 498, 3086, 303, 6974, 1, 31, 5982, 121, 7, 144, 31, 14, 153, 1627, 303, 6325, 31, 622, 2022, 485, 303, 119, 157, 167, 1627, 129, 3086, 303, 561, 200, 297, 1073, 4363, 432, 294, 4531, 4918, 177, 605, 249, 881, 344, 1534, 7560, 70, 7, 935, 427, 14, 35, 13, 608, 5506, 153, 303, 38], [1124, 393, 95, 2590, 767, 292, 7277, 30, 167, 1, 181, 97, 13, 143, 27, 846, 479, 1359, 21, 6161, 5121, 95, 24, 79, 3697, 1, 4827, 736, 287, 346, 96, 254, 878, 95, 11, 155, 268, 180, 1567, 2250]]

# %% [markdown]
# ###  decoder_input_train 처리하기(Summary data)
#
# #### 토크나이저 가져오고 decoder_input_train 데이터 넣기

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)
print('=3')
# Out:
# =3

# %%
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 11614
# 등장 빈도가 5번 이하인 희귀 단어의 수: 8927
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 2687
# 단어 집합에서 희귀 단어의 비율: 76.86412949888066
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 5.4466152143564965

# %%
tar_vocab = 2700
tar_tokenizer = Tokenizer(num_words=tar_vocab) 
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# 잘 변환되었는지 확인
print('input')
print('input ',decoder_input_train[:5])
print('target')
print('decoder ',decoder_target_train[:5])
# Out:
# input
# input  [[1, 71, 69, 147, 51, 514, 31, 2032], [1, 11, 42, 583, 79], [1, 1879, 521, 594], [1, 3, 67, 219, 65, 56, 17], [1, 336]]
# target
# decoder  [[71, 69, 147, 51, 514, 31, 2032, 2], [11, 42, 583, 79, 2], [1879, 521, 594, 2], [3, 67, 219, 65, 56, 17, 2], [336, 2]]

# %% [markdown]
# ##### 주의사항
#
# 전체 데이터에서 빈도수가 낮은 단어가 삭제되었다는 것은 빈도수가 낮은 단어만으로 구성되었던 샘플들은 이제 빈(empty) 샘플이 되었을 가능성 有
#
# ##### 요약문에서 길이가 0이 된 샘플들의 인덱스를 받아오기
#
# 요약문인 decoder_input에는 sostoken, decoder_target에는 eostoken이 추가된 상태이고, 이 두 토큰은 모든 샘플에서 등장하므로 빈도수가 샘플 수와 동일하게 매우 높으므로 단어 집합 제한에도 삭제 X.
#
#
# 그래서 이제 길이가 0이 된 요약문의 실제 길이는 1로 나온다. 길이 0이 된 decoder_input에는 sostoken, decoder_target에는 eostoken만 남아 있기 때문
#
#
# #### 훈련데이터, 평가데이터에 대해 요약문의 길이가 1인 경우의 인덱스 각각 drop_train과 drop_test에 라는 변수에 저장 - 해당 샘플은 삭제 예정

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

#트레인 셋 길이 1인 샘플삭제
encoder_input_train = [sentence for index, sentence in enumerate(encoder_input_train) if index not in drop_train]
decoder_input_train = [sentence for index, sentence in enumerate(decoder_input_train) if index not in drop_train]
decoder_target_train = [sentence for index, sentence in enumerate(decoder_target_train) if index not in drop_train]

#타겟 셋 길이 1인 샘플삭제
encoder_input_test = [sentence for index, sentence in enumerate(encoder_input_test) if index not in drop_test]
decoder_input_test = [sentence for index, sentence in enumerate(decoder_input_test) if index not in drop_test]
decoder_target_test = [sentence for index, sentence in enumerate(decoder_target_test) if index not in drop_test]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 0
# 삭제할 테스트 데이터의 개수 : 0
# 훈련 데이터의 개수 : 60093
# 훈련 레이블의 개수 : 60093
# 테스트 데이터의 개수 : 14959
# 테스트 레이블의 개수 : 14959

# %% [markdown]
# ### Padding
# 서로 다른 길이의 샘플들을 병렬 처리하기 위해 같은 길이로 맞춰주는 패딩 작업 실시.
#
# 아까 정해두었던 최대 길이로 패딩. text_max_len = 80 ,summary_max_len = 8
#
# 최대 길이보다 짧은 데이터들은 뒤의 공간에 숫자 0을 넣어 최대 길이로 길이 맞추기

# %%
#인코더 트레인, 테스트셋
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')

#디코더 트레인셋 - 인풋과 타겟
decoder_input_train = pad_sequences(decoder_input_train, maxlen=summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=summary_max_len, padding='post')

#디코더 테스트셋 - 인풋과 타겟
decoder_input_test = pad_sequences(decoder_input_test, maxlen=summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=summary_max_len, padding='post')
print('=3')
# Out:
# =3

# %% [markdown]
# ### 전처리 완료!

# %% [markdown]
# ## 모델 설계하기
#
# 함수형 API를 이용해서 인코더를 설계
#
# - 임베딩 벡터 차원 = 128
#
# - hidden state의 크기 = 256 ( LSTM에서 얼만큼의 수용력(capacity)를 가질지를 정하는 파라미터)
#
# - 인코더의 LSTM은 총 3개의 층으로 구성해서 모델의 복잡도를 높임. hidden state의 크기를 늘리는 것이 LSTM 층 1개의 용량을 늘린다면, 3개의 층을 사용하는 것은 모델의 용량을 늘림.
#
# - 3개의 층을 지나서 인코더로부터 나온 출력 벡터는 디코더로 전달
#
# #### recurrent dropout 이용
#
# drop out?
# - 레이어의 weight를 랜덤으로 생략하여 모델의 과적합(overfitting)을 방지
#
#
# recurrent dropout?
# - dropout을 레이어가 아닌 time step마다 해주는 방식
# - 즉 time step의 입력을 랜덤으로 생략. regularization을 해주는 효과
# - 과적합 방지

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# 디코더 설계
#
# 디코더의 임베딩 층과 LSTM을 설계하는 것은 인코더와 거의 동일. 하지만 LSTM의 입력을 정의할 때, initial_state의 인자값으로 인코더의 hidden state와 cell state의 값을 넣어야 함

# %%
# 디코더 설계
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs) 

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 80, 128)      1280000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 80, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 80, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    345600      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 80, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 2700)   693900      lstm_3[0][0]
# ==================================================================================================
# Total params: 4,158,604
# Trainable params: 4,158,604
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# 디코더의 출력층에서는 Summary의 단어장인 tar_vocab의 수많은 선택지 중 하나의 단어를 선택하는 다중 클래스 분류 문제를 풀어야 함. 그렇기 때문에 Dense의 인자로 tar_vocab을 주고, 활성화 함수로 소프트맥스 함수를 사용

# %% [markdown]
# ## 어텐션 메커니즘으로 성능 향상시키기
# TensorFlow에 이미 구현된 어텐션 함수를 가져와서 디코더의 출력층에 결합
#
#
# <Bahdanau 스타일 어텐션>

# %%
from tensorflow.keras.layers import AdditiveAttention

# 어텐션 층(어텐션 함수)
attn_layer = AdditiveAttention(name='attention_layer')

# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out = attn_layer([decoder_outputs, encoder_outputs])


# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input) #여기 안에다가 만든 연결점을 넣음

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 80, 128)      1280000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 80, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 80, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    345600      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 80, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AdditiveAttent (None, None, 256)    256         lstm_3[0][0]
#                                                                  lstm_2[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 512)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, None, 2700)   1385100     concat_layer[0][0]
# ==================================================================================================
# Total params: 4,850,060
# Trainable params: 4,850,060
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 모델 훈련하기
#
# 컴파일 진행
#
# ##### 함수 EarlyStopping - 조기 종료 함수 : 특정 조건 충족시 훈련 종료
#
#
# #### es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
#
#
# 위 코드에서는 val_loss(검증 데이터의 손실)을 관찰하다가, 검증 데이터의 손실이 줄어들지 않고 증가하는 현상이 2회(patience=2) 관측되면 학습을 멈추도록 설정
#
# -> EarlyStopping이 작동한다면 epochs가 아무리 크게 설정되어 있어도 모델 훈련을 최적점에서 멈출 수 있다.

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, \
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test), \
          batch_size=256, callbacks=[es], epochs=50)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 248s 1s/step - loss: 2.8596 - val_loss: 2.5688
# Epoch 2/50
# 235/235 [==============================] - 237s 1s/step - loss: 2.5091 - val_loss: 2.4049
# Epoch 3/50
# 235/235 [==============================] - 235s 1s/step - loss: 2.3513 - val_loss: 2.2709
# Epoch 4/50
# 235/235 [==============================] - 234s 997ms/step - loss: 2.2288 - val_loss: 2.1891
# Epoch 5/50
# 235/235 [==============================] - 234s 995ms/step - loss: 2.1438 - val_loss: 2.1367
# Epoch 6/50
# 235/235 [==============================] - 234s 996ms/step - loss: 2.0783 - val_loss: 2.0955
# Epoch 7/50
# 235/235 [==============================] - 233s 991ms/step - loss: 2.0254 - val_loss: 2.0702
# Epoch 8/50
# 235/235 [==============================] - 232s 985ms/step - loss: 1.9800 - val_loss: 2.0488
# Epoch 9/50
# 235/235 [==============================] - 231s 983ms/step - loss: 1.9394 - val_loss: 2.0259
# Epoch 10/50
# 235/235 [==============================] - 230s 978ms/step - loss: 1.9034 - val_loss: 2.0163
# Epoch 11/50
# 235/235 [==============================] - 230s 979ms/step - loss: 1.8697 - val_loss: 2.0067
# Epoch 12/50
# 235/235 [==============================] - 232s 989ms/step - loss: 1.8387 - val_loss: 1.9962
# Epoch 13/50
# 235/235 [==============================] - 231s 984ms/step - loss: 1.8094 - val_loss: 1.9898
# Epoch 14/50
# 235/235 [==============================] - 231s 983ms/step - loss: 1.7834 - val_loss: 1.9817
# Epoch 15/50
# 235/235 [==============================] - 229s 975ms/step - loss: 1.7579 - val_loss: 1.9802
# Epoch 16/50
# 235/235 [==============================] - 230s 978ms/step - loss: 1.7340 - val_loss: 1.9818
# Epoch 17/50
# 235/235 [==============================] - 231s 981ms/step - loss: 1.7116 - val_loss: 1.9802
# Epoch 00017: early stopping

# %% [markdown]
# ## 인퍼런스 모델 구현하기 - 실제 동작용

# %% [markdown]
# 테스트 단계에서는 정수 인덱스 행렬로 존재하던 텍스트 데이터를 실제 데이터로 복원해야 하므로, 필요한 3개의 사전을 아래와 같이 미리 준비

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

print('=3')
# Out:
# =3

# %% [markdown]
# #### seq2seq는 훈련할 때와 실제 동작할 때(인퍼런스 단계)의 방식이 다르므로 그에 맞게 모델 설계를 별개로 진행해야 한다.
#
# 훈련 단계에서는 디코더의 입력부에 정답이 되는 문장 전체를 한꺼번에 넣고 디코더의 출력과 한 번에 비교할 수 있으므로, 인코더와 디코더를 엮은 통짜 모델 제작
#
# 그러나 정답 문장이 없는 인퍼런스 단계에서는 만들어야 할 문장의 길이만큼 디코더가 반복 구조로 동작해야 하기 때문에 부득이하게 인퍼런스를 위한 모델 설계를 별도로 해주어야 함. 이때는 인코더 모델과 디코더 모델을 분리해서 설계

# %% [markdown]
# #### 인코더 설계

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

print('=3')
# Out:
# =3

# %% [markdown]
# #### 어텐션 메커니즘 이용하는 디코더 설계

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf = attn_layer([decoder_outputs2, decoder_hidden_state_input])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

print('=3')
# Out:
# =3

# %% [markdown]
# #### 인퍼런스 단계에서 단어 시퀸스를 완성하는 함수 설계

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence
print('=3')
# Out:
# =3

# %% [markdown]
# ## 모델 테스트하기
#
# src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
# tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
# tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음
#
#
# ### 정수 시퀸스를 텍스트 시퀸스로 변환하는 함수 만들기
#
#
# - Text의 정수 시퀀스에서는 패딩을 위해 사용되는 숫자 0을 제외
# - Summary의 정수 시퀀스에서는 패딩을 위해 사용되는 숫자 0, 시작 토큰의 인덱스, 종료 토큰의 인덱스를 출력에서 제외

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if (i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if ((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

print('=3')
# Out:
# =3

# %% [markdown]
# 테스트 데이터 약 50개의 샘플에 대해서 실제 요약과 예측된 요약을 비교

# %%
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : switch kiwi berry perfect blend tangy tart sweet delicious dose kiwi flavor berry taste drink bubbly better soda clean sticky fruit juice added sugar added anything else bad healthy drink could trick us believing bad good things say switch drinks cannot think one bad thing drink would perfect substitute soda whatever would normally drink soda sandwich chips pizza tacos grapes cheese crackers nachos
# 실제 요약 : perfect blend of flavor healthy
# 예측 요약 :  sweet and sweet
#
#
# 원문 : boxer enjoyed treat though eating drank bowl full water maybe lot sodium real surprise came next day though suffered loss bowel control never went house since got year ago afterwards took hike could seem stop going bowel movements mile hike watery still acting back normal self guess makes sense would trust butcher group people know trust dog treats made countries eat dogs
# 실제 요약 : made my dog sick
# 예측 요약 :  my dog loves these
#
#
# 원문 : six cans smashed received maybe pack better shipment send smashed cans
# 실제 요약 : smashed cans
# 예측 요약 :  damaged cans
#
#
# 원문 : bought one saw one exactly like big box store going back
# 실제 요약 : half the price elsewhere
# 예측 요약 :  good
#
#
# 원문 : sure much like product always little concerned puppies might choke greenies tend bit small comes oral hygiene actually prefer cet chews oral hygiene chews petite dogs chews said already know like greenies seems best price anywhere
# 실제 요약 : best price
# 예측 요약 :  great product
#
#
# 원문 : great product well worth subscribe save price great tasting product brand name delivered often needed could ask
# 실제 요약 : are the best
# 예측 요약 :  great product
#
#
# 원문 : best salad dressing also good cold ham salad kraft miracle whip salad cannot beat
# 실제 요약 : great dressing
# 예측 요약 :  not worth the money
#
#
# 원문 : family generally likes indian food surprisingly like however year old today got could eat lentils rice stomach ache would still eat sent warmed left overs school product cheap great stand ideas need quick dinner two pouches lentils one chick peas young family easily servings left feeding teenagers sure would need heck lot rice salad fruit veggie makes fabulous quick meal minutes keep several tasty bite products hand times
# 실제 요약 : great product but pricey
# 예측 요약 :  great for quick meal
#
#
# 원문 : stool cant describe way drink one day go twice day feel better around
# 실제 요약 : the get regular version is nice
# 예측 요약 :  great tea
#
#
# 원문 : one best english breakfast tea ever tasted flavor good certainly per bag worth buy give try disappointed
# 실제 요약 : great quality tea
# 예측 요약 :  best tea ever
#
#
# 원문 : despite several get rid industrial plastic smell soft rubber parts toy dog absolutley interest despite favorite treats inside assume finds smell offensive ever take interest keep close eye rubber rope seems like something may chew fairly quickly
# 실제 요약 : too smelly dog will not touch it
# 예측 요약 :  not for my dog
#
#
# 원문 : save money get better results get flavoring fries much better buying bottle malt vinegar salt find particular flavorful convenient
# 실제 요약 : stick to real salt and vinegar
# 예측 요약 :  good but not great
#
#
# 원문 : flavor great added iced tea iced coffee milk smoothies
# 실제 요약 : love it
# 예측 요약 :  great tea
#
#
# 원문 : use coffee home inexpensive espresso machine amazing flavor bitter burned like brands buy coffee big want run try think love produces smooth brown foam smell cannot resist
# 실제 요약 : excellent coffee
# 예측 요약 :  great coffee
#
#
# 원문 : two black labs love mix eagle pack dry food eat like starving looking canned dog food could order online delivered quickly shipping fast tried eagle pack beef right away found one dog food reviews listed five star dog foods dogs leaving food bowls like started looking reviews ingredients pricing one best everything matter think dogs love look healthier another plus two flavors amazon prime eligible fast convenient
# 실제 요약 : my dogs cannot wait to eat
# 예측 요약 :  great for dogs
#
#
# 원문 : love fact drink neither tangy sweet perfect therefore quenches thirst without leaving taste
# 실제 요약 : my favorite drink
# 예측 요약 :  great
#
#
# 원문 : wife male cat throws everything except food cats prefer food wet food tried also great quality good price
# 실제 요약 : great food
# 예측 요약 :  my cats love this
#
#
# 원문 : bought mistake glad imagine crunchy peanut bar tastes good good diabetic use carbs worth grams bar try enjoy
# 실제 요약 : great mistake
# 예측 요약 :  not good
#
#
# 원문 : like expresso coffee like iced coffees stands reason would like product recommend ice quite fine strong coffee refreshing coffee tastes fresh actually expected purchase future morning caffeine run recommend people long strong iced coffees particularly sweet happy mornings
# 실제 요약 : quite yummy actually strong not very sweet
# 예측 요약 :  good coffee
#
#
# 원문 : received item product good however item less grocery thought one box order order
# 실제 요약 : misleading
# 예측 요약 :  not what expected
#
#
# 원문 : used try smash dogs pill moist food dog would somehow pick would find pill floor pop pill dog jumps hand dont think even chews makes giving pills much easier smells little like bacon mm bacon
# 실제 요약 : my dog goes nuts for these
# 예측 요약 :  dogs love it
#
#
# 원문 : granola outside make appealing flavored rawhide uploaded photos show rawhide granola layer sum dog getting rest life loves rawhide keeps teeth healthy brainer probably favorite rawhide treat also loves regular busy busy even better
# 실제 요약 : long lasting dog favorite
# 예측 요약 :  great for training
#
#
# 원문 : ok fair always lavazza illy hand wanted try something different lower cost us seems bitter taste impressed yet know got bad batch point even considering throwing getting lavazza bought brick use pressure machine also find starbucks weird aftertaste like beans roasted possibly problem far made cups stars give even used different milk steaming thinking could possibly culprit still bitter sour certainly coffee
# 실제 요약 : bitter taste
# 예측 요약 :  worst ever
#
#
# 원문 : read students chewing gum better tests study plus caffeine always helps concentrate better get done decided try jolt gum combine two works well
# 실제 요약 : love it
# 예측 요약 :  gum
#
#
# 원문 : formula love packs great easy throw dp bag formula easy lo tummy excessive gas constipation easy lil buddy go back forth breast milk
# 실제 요약 : great formula for babies
# 예측 요약 :  great for milk
#
#
# 원문 : two dogs pitbull mix toy fox terrier neither one accustomed receiving dog treats regular basis something treats stiff biscuit type really sure mean ranch style made think going smell like ranch dressing first neither one dogs ate treats whole gonna eat eat treats keep getting ate came back pantry beg get bag like enough catch toss treats air gobble immediately like natural lot dog food products market stuff goes nasty even want touch bare hands problem
# 실제 요약 : good treat
# 예측 요약 :  my dog loved them
#
#
# 원문 : good enough would buy coffee pot work like french roasts solid cup coffee
# 실제 요약 : would buy it again
# 예측 요약 :  good coffee
#
#
# 원문 : look pantry would see shelf many tea varieties would make head spin tea drink every afternoon evening especially need drinking twig tea ten years love brand subscribe save option best price find highly recommended
# 실제 요약 : my go to tea
# 예측 요약 :  great tea
#
#
# 원문 : product good way expensive almost box get pancakes biscuits disappointed
# 실제 요약 : good product too expensive
# 예측 요약 :  flour
#
#
# 원문 : fantastic product arrived fresh good price subscribe save keeping subscription
# 실제 요약 : yummy
# 예측 요약 :  great product
#
#
# 원문 : nearly tasteless faint bit saltiness real flavor amount money buy enough truffle oil flavor dozen dishes least jar cute
# 실제 요약 : do not waste your time
# 예측 요약 :  not bad
#
#
# 원문 : best coffee tried tried many types cups wish could packaged larger package cups sold cheaper
# 실제 요약 : the best of what tried
# 예측 요약 :  great coffee
#
#
# 원문 : popchips good eat quite chips low calorie low fat content taste like cardboard super good
# 실제 요약 : love popchips
# 예측 요약 :  good chips
#
#
# 원문 : ordered basmati rice arrived today extra long grain rice problems order arrived product pictured basmati rice extra long grain basmati paid pound bag basmati rice sure happened feel like paid premium price rice even want beware get rice pictured pay premium price disappointment top even option return according amazon return policy even though sealed
# 실제 요약 : wrong product
# 예측 요약 :  rice crackers
#
#
# 원문 : lived kenya years cold hibiscus tea favorite daily drink loaded vitamin antioxidents bought hibiscus blossoms local market brewed room temperature water hours back us half gallon times read several stating hibiscus tea addition health benefits lowers blood pressure
# 실제 요약 : outstanding for iced tea
# 예측 요약 :  great tea
#
#
# 원문 : bought husband use starbucks like sitting cabinet backup case run doughnut shop
# 실제 요약 : not pod
# 예측 요약 :  great taste
#
#
# 원문 : could find whole cardamom local supermarkets ethnic markets far luckily found whole cardamom perfect first time ordered spice online admit felt bit odd first experience would hesitate
# 실제 요약 : yum delicious
# 예측 요약 :  love this stuff
#
#
# 원문 : real chocoholic need cocoa hand buy anywhere found amazon best price shared family friends kept couple dutch process wish would bring back dark baking cocoa right recipes lot
# 실제 요약 : for the baker
# 예측 요약 :  great tasting cocoa
#
#
# 원문 : bad coconut water come close nirvana thai coconuts nirvana much deeper richer taste
# 실제 요약 : good but not great
# 예측 요약 :  coconut water
#
#
# 원문 : happy found amazon com eat every morning hand blessing price great bars everyone try wonderful
# 실제 요약 : special bars
# 예측 요약 :  love these
#
#
# 원문 : kids thought okay like odd taste love white cake cookie mix fabulous
# 실제 요약 : did not like taste
# 예측 요약 :  not good
#
#
# 원문 : buying locally always good better price
# 실제 요약 : good stuff
# 예측 요약 :  great product
#
#
# 원문 : crunchy perfect however buy find asian market price ridiculous
# 실제 요약 : delicious do not buy here
# 예측 요약 :  great price
#
#
# 원문 : like whole line pastas little shells taste great great alternative allergic wheat
# 실제 요약 : love these little shells
# 예측 요약 :  great pasta
#
#
# 원문 : shipping fast customer service excellent disappointed product product claims give energy reduce appetite yet drinking tea never experienced decrease appetite energy would buy
# 실제 요약 : disappointed product
# 예측 요약 :  great tea
#
#
# 원문 : expecting flavor chocolate glazed donut take bite forgot really coffee smell good aftertaste crazy person like instant general mills international come rectangular cans always described perfume flavor kind fake aftertaste understand mean think stick different coffee blends roasts natural leave flavoring creamers additions make cup coffee
# 실제 요약 : smells good but has flavored coffee aftertaste
# 예측 요약 :  not bad
#
#
# 원문 : rice best tasting make home rice also wonderful aroma unfortunately hard come seattle area store shelves find compare amazon stock delivered time yeah amazon
# 실제 요약 : best tasting rice
# 예측 요약 :  best rice ever
#
#
# 원문 : ordered several jars cacao bliss yet try product like like coconut chocolate must try
# 실제 요약 : so good eat it from the jar
# 예측 요약 :  great taste
#
#
# 원문 : soooo cute give nothing best sweet friendly saw product first ignored turned back stuck little paw large shape get ball cute lil guy also since color blind like dogs course ball interesting rolled around house happily red part great actually clean unlike furry toys happy company actually took time effort create great product dog mind thanks
# 실제 요약 : love my dog
# 예측 요약 :  my dog loves this stuff
#
#
# 원문 : tea great quality tasted like dessert packaging great reasonable time definately purchasing
# 실제 요약 : yum worth it
# 예측 요약 :  great tea

# %% [markdown]
# ##### 워드 임베딩 + RNN의 합작품
#
# 많은 결과가 출력이 되는데, 기존의 요약과는 다른 요약을 출력하면서도 원문의 내용을 담고 있는 의미 있는 요약들이 보인다. 심지어 일부 요약의 경우에는 원문에 없던 단어를 사용해서 요약을 하기도 함!
#
# ##### 성능 개선 방법
#
# - seq2seq와 어텐션의 자체의 조합을 좀 더 좋게 수정
# - 빔 서치(beam search)
# - 사전 훈련된 워드 임베딩(pre-trained word embedding)
# - 인코더 - 디코더 자체의 구조를 새로이 변경한 하는 트랜스포머(Transformer)

# %% [markdown]
# ## 추출적 요약 해보기
#  이미 본문에 존재하는 단어구, 문장을 뽑아서 요약으로 삼는 요약 방법
#
#  #### Summa 패키지의 모듈 summarize 이용!

# %%
import requests
from summa.summarizer import summarize

#데이터 다운로드
text = requests.get('http://rare-technologies.com/the_matrix_synopsis.txt').text

print("원문 :",text[:1500])
# Out:
# 원문 : The screen is filled with green, cascading code which gives way to the title, The Matrix.
#
# A phone rings and text appears on the screen: "Call trans opt: received. 2-19-98 13:24:18 REC: Log>" As a conversation takes place between Trinity (Carrie-Anne Moss) and Cypher (Joe Pantoliano), two free humans, a table of random green numbers are being scanned and individual numbers selected, creating a series of digits not unlike an ordinary phone number, as if a code is being deciphered or a call is being traced.
#
# Trinity discusses some unknown person. Cypher taunts Trinity, suggesting she enjoys watching him. Trinity counters that "Morpheus (Laurence Fishburne) says he may be 'the One'," just as the sound of a number being selected alerts Trinity that someone may be tracing their call. She ends the call.
#
# Armed policemen move down a darkened, decrepit hallway in the Heart O' the City Hotel, their flashlight beam bouncing just ahead of them. They come to room 303, kick down the door and find a woman dressed in black, facing away from them. It's Trinity. She brings her hands up from the laptop she's working on at their command.
#
# Outside the hotel a car drives up and three agents appear in neatly pressed black suits. They are Agent Smith (Hugo Weaving), Agent Brown (Paul Goddard), and Agent Jones (Robert Taylor). Agent Smith and the presiding police lieutenant argue. Agent Smith admonishes the policeman that they were given specific orders to contact the agents first, for their

# %% [markdown]
# #### Summa의 summarize()의 인자로 사용되는 값
#
# - text (str) : 요약할 테스트.
# - ratio (float, optional) – 요약문에서 원본에서 선택되는 문장 비율. 0~1 사이값
# - words (int or None, optional) – 출력에 포함할 단어 수.
# - 만약, ratio와 함께 두 파라미터가 모두 제공되는 경우 ratio는 무시한다.
# - split (bool, optional) – True면 문장 list / False는 조인(join)된 문자열을 반환

# %% [markdown]
# ##### Summa의 summarize는 문장 토큰화를 별도로 하지 않더라도 내부적으로 문장 토큰화를 수행. 그렇기 때문에 문장 구분이 되어있지 않은 원문을 바로 입력으로 넣을 수 있다.
#
#
# 비율을 적게 주어서 요약문으로 선택되는 문장의 개수를 줄이기 : 원문의 0.005%만을 출력하도록 설정

# %%
print('Summary:')
print(summarize(text, ratio=0.005))
# Out:
# Summary:
# Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.
# Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.

# %%
#결괏값 리스트로 받기
print('Summary:')
print(summarize(text, ratio=0.005, split=True))
# Out:
# Summary:
# ['Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.', 'Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.']

# %%
#출력 단어수 설정으로 요약문 크기 조절
print('Summary:')
print(summarize(text, words=50))
# Out:
# Summary:
# Trinity takes Neo to Morpheus.
# Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.
# Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.
